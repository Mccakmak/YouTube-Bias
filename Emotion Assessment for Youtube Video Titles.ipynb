# %%
import pandas as pd
from transformers import pipeline

# %%
# Model
classifier = pipeline("text-classification",model='bhadresh-savani/distilbert-base-uncased-emotion', return_all_scores=True)
# Out:
# All model checkpoint layers were used when initializing TFDistilBertForSequenceClassification.
#
# All the layers of TFDistilBertForSequenceClassification were initialized from the model checkpoint at bhadresh-savani/distilbert-base-uncased-emotion.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForSequenceClassification for predictions without further training.
# C:\Users\mccak\AppData\Local\Programs\Python\Python39\lib\site-packages\transformers\pipelines\text_classification.py:89: UserWarning: `return_all_scores` is now deprecated, use `top_k=1` if you want similar functionnality
#   warnings.warn(

# %%
# Data
videos = pd.read_excel("data/depth_documents.xlsx")
videos
# Out:
#                                                    title     video_id  \
# 0      China Navy to BBC: 'Stay away from islands' - ...  LVeKbEgn50o
# 1      Nike, H&M face backlash in China over Uighur s...  qC_qOoBFsMc
# 2      What do you do when someone just doesn't like ...  Y4gly9n9RBo
# 3                         99 Years Later... We Solved It  JFFhD5HeByM
# 4      Elon Musk talks Twitter, Tesla and how his bra...  cdZZpaB2kDM
# ...                                                  ...          ...
# 14327  The art of focus – a crucial ability | Christi...  xF80HzqvAoA
# 14328  Why We Fear And Hold Back From What We Want | ...  tFDRXgDUea4
# 14329  5 steps to designing the life you want | Bill ...  SemHh0n19LA
# 14330  Master Shi Heng Yi – 5 hindrances to self-mast...  4-079YIasck
# 14331  What do you do when someone just doesn't like ...  Y4gly9n9RBo
#
#                                                url       channel    parent_id  \
# 0      https://www.youtube.com/watch?v=LVeKbEgn50o      BBC News  nbBsh46aSz4
# 1      https://www.youtube.com/watch?v=qC_qOoBFsMc       DW News  s_eNkqwp_LA
# 2      https://www.youtube.com/watch?v=Y4gly9n9RBo    TEDx Talks  s_eNkqwp_LA
# 3      https://www.youtube.com/watch?v=JFFhD5HeByM  Physics Girl  tcKw5jiT6wg
# 4      https://www.youtube.com/watch?v=cdZZpaB2kDM           TED  tcKw5jiT6wg
# ...                                            ...           ...          ...
# 14327  https://www.youtube.com/watch?v=xF80HzqvAoA    TEDx Talks  4AzpmZ7AjaQ
# 14328  https://www.youtube.com/watch?v=tFDRXgDUea4    TEDx Talks  4AzpmZ7AjaQ
# 14329  https://www.youtube.com/watch?v=SemHh0n19LA    TEDx Talks  vj-91dMvQQo
# 14330  https://www.youtube.com/watch?v=4-079YIasck    TEDx Talks  vj-91dMvQQo
# 14331  https://www.youtube.com/watch?v=Y4gly9n9RBo    TEDx Talks  vj-91dMvQQo
#
#                                             parent  depth lang
# 0      https://www.youtube.com/watch?v=nbBsh46aSz4      1   en
# 1      https://www.youtube.com/watch?v=s_eNkqwp_LA      1   en
# 2      https://www.youtube.com/watch?v=s_eNkqwp_LA      1   en
# 3      https://www.youtube.com/watch?v=tcKw5jiT6wg      1   en
# 4      https://www.youtube.com/watch?v=tcKw5jiT6wg      1   en
# ...                                            ...    ...  ...
# 14327  https://www.youtube.com/watch?v=4AzpmZ7AjaQ      5   en
# 14328  https://www.youtube.com/watch?v=4AzpmZ7AjaQ      5   en
# 14329  https://www.youtube.com/watch?v=vj-91dMvQQo      5   en
# 14330  https://www.youtube.com/watch?v=vj-91dMvQQo      5   en
# 14331  https://www.youtube.com/watch?v=vj-91dMvQQo      5   en
#
# [14332 rows x 8 columns]

# %%
# Example titles
titles = videos.title.astype(str).values.tolist()
titles[:10]
# Out:
# ["China Navy to BBC: 'Stay away from islands' - BBC News",
#  'Nike, H&M face backlash in China over Uighur stance | DW News',
#  "What do you do when someone just doesn't like you? | Daryl Davis | TEDxCharlottesville",
#  '99 Years Later... We Solved It',
#  'Elon Musk talks Twitter, Tesla and how his brain works — live at TED2022',
#  'MOFA: BBC is not trusted even in the UK',
#  'By following @CNN , we find how they make fake news about Xinjiang',
#  'British researcher exposes Western propaganda against China',
#  'Do we see reality as it is? | Donald Hoffman',
#  'By following @CNN , we find how they make fake news about Xinjiang']

# %%
# Emotion analysis for all titles using our model
all_title_emotions = classifier(titles)

# %%
title_emotion_labels = []
title_emotion_scores = []


# Find the maximum score for each prediction and assign its label
for title_emotions in all_title_emotions:
    
    max_score = 0
    emotion_label = None
    for emotion in title_emotions:
        if emotion['score'] > max_score:
            max_score = emotion['score']
            emotion_label = emotion['label']
            
    title_emotion_labels.append(emotion_label)
    title_emotion_scores.append(max_score)

# %%
# Add new values into the dataframe
videos['emotion'] = pd.Series(title_emotion_labels)
videos['score'] = pd.Series(title_emotion_scores)

# %%
# Save 
videos.to_csv("data/depth_videos_emotion.csv", index=False)
